# %%
import tensorflow as tf
import pandas as pd
import seaborn as sns

from tensorflow.keras import datasets, layers, models
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D , Flatten , BatchNormalization , Lambda , Activation , Dropout

import matplotlib.pyplot as plt

# %%
TARGET_X = 256
TARGET_Y = 256
BATCH_SIZE = 32
CLASS_NUM = 50
EPOCH = 15

# %%
def append_ext(fn):
    return fn+".png"

train_classes=pd.read_csv('./multiclass.csv', dtype=str)
#Changing the attribute ids into lists instead of str seperated by a ' ' to be able to count them
train_classes['attribute_ids']=train_classes['attribute_ids'].str.split(' ')
train_classes["id"]=train_classes["id"].apply(append_ext)


print('train : \n', train_classes.head())
# Out:
# train :
#                       id attribute_ids
# 0  1000fe2e667721fe.png          [51]
# 1  10041eb49b297c08.png          [51]
# 2  100501c227f8beea.png          [13]
# 3  1008abd71f3ed5bc.png          [70]
# 4  100a0dcde728cb36.png          [51]

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255.,validation_split=0.2)

train_gen = datagen.flow_from_dataframe(dataframe= train_classes,
                                             directory='../data',
                                             x_col="id",
                                             y_col="attribute_ids",
                                             subset="training",
                                             target_size = (TARGET_X,TARGET_Y),
                                             batch_size=BATCH_SIZE,
                                             class_name='categorical')

valid_gen = datagen.flow_from_dataframe(dataframe= train_classes,
                                             directory='../data',
                                             x_col="id",
                                             y_col="attribute_ids",
                                             subset="validation",
                                             target_size = (TARGET_X,TARGET_Y),
                                             batch_size=BATCH_SIZE,
                                             class_name='categorical')
# Out:
# Found 17670 validated image filenames belonging to 50 classes.
# Found 4417 validated image filenames belonging to 50 classes.

# %%
model = Sequential()

model.add(Conv2D(96, 7, strides=3, padding='same', input_shape=(TARGET_X,TARGET_Y,3)))
model.add(Lambda(tf.nn.local_response_normalization))
model.add(Activation('relu'))
model.add(MaxPooling2D(3, strides=2))
model.add(Conv2D(256, 5, strides=3, padding='same'))
model.add(Lambda(tf.nn.local_response_normalization))
model.add(Activation('relu'))
model.add(MaxPooling2D(3, strides=2))
model.add(Dropout(0.5))
model.add(Conv2D(384, 3, strides=4, padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(384, 3, strides=4, padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(256, 3, strides=4, padding='same'))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dense(CLASS_NUM, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 86, 86, 96)        14208
# _________________________________________________________________
# lambda (Lambda)              (None, 86, 86, 96)        0
# _________________________________________________________________
# activation (Activation)      (None, 86, 86, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 42, 42, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 256)       614656
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 14, 14, 256)       0
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 384)         885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 2, 2, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 1, 384)         1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 1, 1, 384)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 256)         884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                204850
# =================================================================
# Total params: 21,765,298
# Trainable params: 21,765,298
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers

optimizer = optimizers.Adam(lr=0.0001)
model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy",  "Precision", "Recall", "AUC",tf.keras.metrics.TopKCategoricalAccuracy()])

STEP_SIZE_TRAIN = train_gen.n//train_gen.batch_size
STEP_SIZE_VALID = valid_gen.n//valid_gen.batch_size

history = model.fit(train_gen,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_gen,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=EPOCH,
                    verbose=1)
# Out:
# C:\Python\Python39\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/15
# 552/552 [==============================] - 395s 686ms/step - loss: 2.0764 - accuracy: 0.3930 - precision: 0.4027 - recall: 0.0689 - auc: 0.9198 - top_k_categorical_accuracy: 0.7952 - val_loss: 1.8038 - val_accuracy: 0.4171 - val_precision: 0.7497 - val_recall: 0.1316 - val_auc: 0.9424 - val_top_k_categorical_accuracy: 0.8400
# Epoch 2/15
# 552/552 [==============================] - 432s 783ms/step - loss: 1.7723 - accuracy: 0.4288 - precision: 0.5831 - recall: 0.1429 - auc: 0.9436 - top_k_categorical_accuracy: 0.8415 - val_loss: 1.6266 - val_accuracy: 0.5315 - val_precision: 0.6441 - val_recall: 0.3143 - val_auc: 0.9561 - val_top_k_categorical_accuracy: 0.8486
# Epoch 3/15
# 552/552 [==============================] - 293s 531ms/step - loss: 1.5868 - accuracy: 0.5338 - precision: 0.6401 - recall: 0.3287 - auc: 0.9551 - top_k_categorical_accuracy: 0.8532 - val_loss: 1.4806 - val_accuracy: 0.5580 - val_precision: 0.6533 - val_recall: 0.4327 - val_auc: 0.9603 - val_top_k_categorical_accuracy: 0.8620
# Epoch 4/15
# 552/552 [==============================] - 345s 626ms/step - loss: 1.4713 - accuracy: 0.5572 - precision: 0.6607 - recall: 0.3906 - auc: 0.9619 - top_k_categorical_accuracy: 0.8648 - val_loss: 1.4221 - val_accuracy: 0.5802 - val_precision: 0.6905 - val_recall: 0.4264 - val_auc: 0.9663 - val_top_k_categorical_accuracy: 0.8712
# Epoch 5/15
# 552/552 [==============================] - 351s 636ms/step - loss: 1.4338 - accuracy: 0.5776 - precision: 0.6755 - recall: 0.4207 - auc: 0.9632 - top_k_categorical_accuracy: 0.8731 - val_loss: 1.3988 - val_accuracy: 0.5847 - val_precision: 0.7102 - val_recall: 0.4389 - val_auc: 0.9656 - val_top_k_categorical_accuracy: 0.8776
# Epoch 6/15
# 552/552 [==============================] - 225s 408ms/step - loss: 1.3797 - accuracy: 0.5807 - precision: 0.6984 - recall: 0.4225 - auc: 0.9659 - top_k_categorical_accuracy: 0.8791 - val_loss: 1.3377 - val_accuracy: 0.5926 - val_precision: 0.6836 - val_recall: 0.4946 - val_auc: 0.9692 - val_top_k_categorical_accuracy: 0.8829
# Epoch 7/15
# 552/552 [==============================] - 224s 406ms/step - loss: 1.2921 - accuracy: 0.6105 - precision: 0.7210 - recall: 0.4781 - auc: 0.9707 - top_k_categorical_accuracy: 0.8843 - val_loss: 1.2775 - val_accuracy: 0.6155 - val_precision: 0.7637 - val_recall: 0.4158 - val_auc: 0.9713 - val_top_k_categorical_accuracy: 0.8875
# Epoch 8/15
# 552/552 [==============================] - 310s 562ms/step - loss: 1.2123 - accuracy: 0.6256 - precision: 0.7347 - recall: 0.4903 - auc: 0.9738 - top_k_categorical_accuracy: 0.8890 - val_loss: 1.2334 - val_accuracy: 0.6295 - val_precision: 0.7771 - val_recall: 0.4334 - val_auc: 0.9738 - val_top_k_categorical_accuracy: 0.8919
# Epoch 9/15
# 552/552 [==============================] - 334s 605ms/step - loss: 1.1727 - accuracy: 0.6387 - precision: 0.7420 - recall: 0.5103 - auc: 0.9750 - top_k_categorical_accuracy: 0.8931 - val_loss: 1.2186 - val_accuracy: 0.6248 - val_precision: 0.7330 - val_recall: 0.5086 - val_auc: 0.9717 - val_top_k_categorical_accuracy: 0.8955
# Epoch 10/15
# 552/552 [==============================] - 273s 496ms/step - loss: 1.1549 - accuracy: 0.6422 - precision: 0.7447 - recall: 0.5275 - auc: 0.9755 - top_k_categorical_accuracy: 0.8965 - val_loss: 1.2060 - val_accuracy: 0.6370 - val_precision: 0.7250 - val_recall: 0.5403 - val_auc: 0.9708 - val_top_k_categorical_accuracy: 0.8989
# Epoch 11/15
# 552/552 [==============================] - 267s 484ms/step - loss: 1.0980 - accuracy: 0.6620 - precision: 0.7567 - recall: 0.5506 - auc: 0.9781 - top_k_categorical_accuracy: 0.8998 - val_loss: 1.1915 - val_accuracy: 0.6411 - val_precision: 0.7602 - val_recall: 0.5111 - val_auc: 0.9738 - val_top_k_categorical_accuracy: 0.9018
# Epoch 12/15
# 552/552 [==============================] - 270s 490ms/step - loss: 1.0586 - accuracy: 0.6753 - precision: 0.7724 - recall: 0.5670 - auc: 0.9798 - top_k_categorical_accuracy: 0.9026 - val_loss: 1.1596 - val_accuracy: 0.6433 - val_precision: 0.7730 - val_recall: 0.4841 - val_auc: 0.9762 - val_top_k_categorical_accuracy: 0.9045
# Epoch 13/15
# 552/552 [==============================] - 312s 565ms/step - loss: 1.0051 - accuracy: 0.6929 - precision: 0.7808 - recall: 0.5976 - auc: 0.9814 - top_k_categorical_accuracy: 0.9054 - val_loss: 1.1701 - val_accuracy: 0.6454 - val_precision: 0.7254 - val_recall: 0.5616 - val_auc: 0.9718 - val_top_k_categorical_accuracy: 0.9071
# Epoch 14/15
# 552/552 [==============================] - 238s 431ms/step - loss: 0.9720 - accuracy: 0.6986 - precision: 0.7884 - recall: 0.6087 - auc: 0.9827 - top_k_categorical_accuracy: 0.9078 - val_loss: 1.1315 - val_accuracy: 0.6562 - val_precision: 0.7583 - val_recall: 0.5505 - val_auc: 0.9748 - val_top_k_categorical_accuracy: 0.9094
# Epoch 15/15
# 552/552 [==============================] - 125s 227ms/step - loss: 0.9450 - accuracy: 0.7003 - precision: 0.7930 - recall: 0.6147 - auc: 0.9843 - top_k_categorical_accuracy: 0.9101 - val_loss: 1.1389 - val_accuracy: 0.6517 - val_precision: 0.7613 - val_recall: 0.5301 - val_auc: 0.9749 - val_top_k_categorical_accuracy: 0.9116

# %%
sns.set_style("whitegrid")
fig, axs = plt.subplots(2, 3, sharex='col', figsize=(20,7))

axs[0,0].plot(history.history['loss'], label='Train loss')
axs[0,0].plot(history.history['val_loss'], label='Validation loss')
axs[0,0].legend(loc='best')
axs[0,0].set_title('Loss')

axs[1,0].plot(history.history['accuracy'], label='Train Accuracy')
axs[1,0].plot(history.history['val_accuracy'], label='Validation accuracy')
axs[1,0].legend(loc='best')
axs[1,0].set_title('Accuracy')

axs[0,1].plot(history.history['precision'], label='Train Precision')
axs[0,1].plot(history.history['val_precision'], label='Validation Precision')
axs[0,1].legend(loc='best')
axs[0,1].set_title('Precision')

axs[1,1].plot(history.history['recall'], label='Train Recall')
axs[1,1].plot(history.history['val_recall'], label='Validation Recall')
axs[1,1].legend(loc='best')
axs[1,1].set_title('Recall')

axs[0,2].plot(history.history['auc'], label='Train AUC')
axs[0,2].plot(history.history['val_auc'], label='Validation AUC')
axs[0,2].legend(loc='best')
axs[0,2].set_title('AUC')

axs[1,2].plot(history.history['top_k_categorical_accuracy'], label='Train Top 5 Accuracy')
axs[1,2].plot(history.history['val_top_k_categorical_accuracy'], label='Validation Top 5 Accuracy')
axs[1,2].legend(loc='best')
axs[1,2].set_title('Top 5 Accuracy')

plt.xlabel('Epochs')
sns.despine()
plt.show()
